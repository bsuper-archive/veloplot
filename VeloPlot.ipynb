# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import utils
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# //anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
CALIBRATION_FILE = "N_matrix_trial9.mat"
DATA_FILE = "sliding10.txt"

utils.print_header(DATA_FILE)
# Out:
# %  Data file recorded 2016/3/16  21:45:56
# %  Stride Frequency         = [4, 4]
# %  Lead In /Lead Out        =
# %  Deltas (Fractional)      = [0.25, 0.25, 0.25],[0.25, 0.25, 0.25]
# %  Phase                    = 32768
# %  Experiment.py
# %  Motor Gains    = [100, 0, 100, 0, 0, 100, 0, 100, 0, 0]

# %%
df = utils.process_data_files(DATA_FILE, CALIBRATION_FILE)
plot_name = str(DATA_FILE.split(".txt")[0])
utils.plot_columns(df, [["TorqueL", "TorqueR"], ["Left Leg Pos", "Right Leg Pos"], ["Fx", "Fy", "Fz"], ["Mx", "My", "Mz"]], 
                   output_filename=plot_name)
# Out:
# Saving image as out/sliding10.png
# Image saved.

# %%
df.head()
# Out:
#        time  Right Leg Pos  Left Leg Pos  Commanded Right Leg Pos  \
# 0  0.000127       3.220976      1.848447                 0.253107
# 1  0.001128       3.221360      1.848063                 0.253107
# 2  0.002129       3.222127      1.848447                 0.253107
# 3  0.003130       3.220976      1.848063                 0.253107
# 4  0.004131       3.222510      1.849214                 0.253107
#
#    Commanded Left Leg Pos  DCR   DCL     GyroX     GyroY     GyroZ  \
# 0                0.253107 -681  1168 -0.059655  0.003196  0.374973
# 1                0.253107 -781  1218 -0.057524  0.002131  0.376038
# 2                0.253107 -807  1168 -0.055394  0.002131  0.376038
# 3                0.253107 -681  1218 -0.057524  0.003196  0.376038
# 4                0.253107 -857  1118 -0.058590  0.004261  0.376038
#
#        ...        TorqueL      VMotorR      VMotorL    AngleZ            Fx  \
# 0      ...      -0.283250 -2667.209319  4574.596894  0.000000  1.768321e-09
# 1      ...      -0.324843 -3058.870012  4770.427240  0.000376  1.562458e-08
# 2      ...      -0.336136 -3157.134409  4569.433692  0.000752  6.962211e-08
# 3      ...      -0.280381 -2667.209319  4770.427240  0.001128  2.135710e-07
# 4      ...      -0.353746 -3356.532139  4378.766547  0.001504  5.168528e-07
#
#              Fy            Fz            Mx            My            Mz
# 0 -8.767885e-09 -5.513987e-09  3.386548e-07  1.600362e-08  3.616464e-07
# 1 -7.747150e-08 -4.872063e-08  2.992295e-06  1.414052e-07  3.195444e-06
# 2 -3.452080e-07 -2.170960e-07  1.333347e-05  6.300926e-07  1.423869e-05
# 3 -1.058951e-06 -6.659581e-07  4.090142e-05  1.932856e-06  4.367826e-05
# 4 -2.562716e-06 -1.611653e-06  9.898352e-05  4.677610e-06  1.057036e-04
#
# [5 rows x 38 columns]
