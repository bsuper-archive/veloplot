# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import utils

# %%
CALIBRATION_FILE = "N_matrix_trial9.mat"
DATA_FILE = "upside_down_2016.03.13_17.18.45_trial3_imudata.txt"

utils.print_header(DATA_FILE)
# Out:
# %  Data file recorded 2016/3/13  17:18:45
# %  Stride Frequency         = [7, 7]
# %  Lead In /Lead Out        =
# %  Deltas (Fractional)      = [0.25, 0.25, 0.25],[0.25, 0.25, 0.25]
# %  Phase                    = 32768
# %  Experiment.py
# %  Motor Gains    = [100, 0, 100, 0, 0, 100, 0, 100, 0, 0]

# %%
df = utils.process_data_files(DATA_FILE, CALIBRATION_FILE)
plot_name = str(DATA_FILE.split(".txt")[0])
utils.plot_columns(df, [["TorqueL", "TorqueR"], ["Left Leg Pos", "Right Leg Pos"], ["Fx", "Fy", "Fz"], ["Mx", "My", "Mz"]], 
                   output_filename=plot_name)
# Out:
# Saving image as out/upside_down_2016.03.13_17.18.45_trial3_imudata
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-e237d3418581> in <module>()
#       2 plot_name = str(DATA_FILE.split(".txt")[0])
#       3 utils.plot_columns(df, [["TorqueL", "TorqueR"], ["Left Leg Pos", "Right Leg Pos"], ["Fx", "Fy", "Fz"], ["Mx", "My", "Mz"]],
# ----> 4                    output_filename=plot_name)
#
# /Users/cemkoc/PROJECTS/research/veloplot/utils.pyc in plot_columns(df, columns, output_dir, output_filename, save_figure)
#     120         print "Saving image as", output_dir + output_filename
#     121         figure.set_size_inches(12, 8)
# --> 122         figure.savefig(output_dir + plot_filename, dpi=700)
#     123         print "Image saved."
#     124
#
# /Users/cemkoc/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in savefig(self, *args, **kwargs)
# ...

# %%
df.head()
# Out:
#        time  Right Leg Pos  Left Leg Pos  Commanded Right Leg Pos  \
# 0  0.000894       6.231413      4.772214                 1.346068
# 1  0.001895       6.231797      4.769146                 1.346068
# 2  0.002896       6.231030      4.766845                 1.346068
# 3  0.003897       6.232180      4.766078                 1.346068
# 4  0.004898       6.231030      4.771447                 1.346068
#
#    Commanded Left Leg Pos  DCR  DCL     GyroX     GyroY     GyroZ  \
# 0                1.346068  380  527  0.177899  0.218379  0.171508
# 1                1.346068  330  928  0.176834  0.216249  0.167247
# 2                1.346068  406  878  0.177899  0.216249  0.167247
# 3                1.346068  280  779  0.177899  0.219444  0.166181
# 4                1.346068  431  377  0.177899  0.218379  0.165116
#
#        ...        TorqueL      VMotorR      VMotorL    AngleZ            Fx  \
# 0      ...       0.145340  1400.960573  1942.911111  0.000000  1.107511e-09
# ...
