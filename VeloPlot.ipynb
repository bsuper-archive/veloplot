# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import utils

# %%
CALIBRATION_FILE = "N_matrix_trial9.mat"
DATA_FILE = "2016.03.06_19.44.56_trial_3_imudata.txt"

utils.print_header(DATA_FILE)
# Out:
# %  Data file recorded 2016/3/6  19:44:56
# %  Stride Frequency         = [7, 7]
# %  Lead In /Lead Out        =
# %  Deltas (Fractional)      = [0.25, 0.25, 0.25],[0.25, 0.25, 0.25]
# %  Phase                    = 32768
# %  Experiment.py
# %  Motor Gains    = [100, 0, 100, 0, 0, 100, 0, 100, 0, 0]

# %%
df = utils.process_data_files(DATA_FILE, CALIBRATION_FILE)
utils.plot_columns(df, [["TorqueL", "TorqueR"], ["Left Leg Pos", "Right Leg Pos"], ["Fx", "Fy", "Fz"], ["Mx", "My", "Mz"]])
# Out:
# Saving image as out/plots.png
# Image saved.

# %%
df.tail()
# Out:
#           time  Right Leg Pos  Left Leg Pos  Commanded Right Leg Pos  \
# 5193  5.200861       4.634158      5.348226               224.399148
# 5194  5.201862       4.634158      5.348609               224.399148
# 5195  5.202863       4.635308      5.350527               224.399148
# 5196  5.203864       4.633774      5.348993               224.399148
# 5197  5.204865       4.634925      5.350143               224.399148
#
#       Commanded Left Leg Pos   DCR   DCL     GyroX     GyroY     GyroZ  \
# 5193              224.399148  3800  3800 -0.160855  0.183225 -0.060720
# 5194              224.399148  3800  3800 -0.157659  0.205596 -0.036219
# 5195              224.399148  3800  3800 -0.154463  0.207727 -0.017044
# 5196              224.399148  3800  3800 -0.149137  0.186421  0.004261
# 5197              224.399148  3800  3800 -0.142745  0.189617  0.027697
#
#         ...      TorqueL       VMotorR       VMotorL    AngleZ        Fx  \
# 5193    ...     1.483190  14295.173238  14295.173238  0.028927 -0.072713
# 5194    ...     1.463177  14295.173238  14295.173238  0.028891 -0.073285
# 5195    ...     1.471182  14295.173238  14295.173238  0.028874 -0.073889
# 5196    ...     1.515212  14295.173238  14295.173238  0.028878 -0.074521
# 5197    ...     1.519214  14295.173238  14295.173238  0.028906 -0.075176
#
#             Fy        Fz        Mx        My        Mz
# 5193  0.083899  0.096516 -6.991368 -3.906984 -1.865856
# 5194  0.072784  0.093979 -6.571003 -3.883963 -1.553127
# 5195  0.061753  0.091460 -6.154239 -3.861363 -1.243603
# 5196  0.050857  0.088974 -5.742916 -3.839228 -0.938656
# 5197  0.040140  0.086534 -5.338751 -3.817612 -0.639566
#
# [5 rows x 38 columns]
