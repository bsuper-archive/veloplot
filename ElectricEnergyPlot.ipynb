# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
import pandas as pd

# rc('font',**{'family':'sans-serif','sans-serif':['Times New Roman']})
# rc('text', usetex=True)

sns.set_style("whitegrid")
sns.set_style("ticks",{'axes.grid' : False, 'grid.linestyle': '--', 'grid.color':'black'})
sns.set_palette("bright")

# %%
# import plotly.plotly as py
# import plotly.tools as tls

# figure, axarr = plt.subplots(1) 

#Drag Energy Values Per Experiment
#[4,6,8,10,14]cms
#These are in milli Joules!!!!!
# y = [[43.7517281399,40.5095916734,46.0396065548,41.3447699641,26.7173180728],
#      [16.0091360348,17.1934198813,19.6689776828,10.963293453,14.7849611848],
#      [7.67721674383,9.54039749662,7.53230578126,7.31788106526,9.78851015352],
#      [1.9878490957,7.79337248744,2.89737072701,11.512361768,3.09771914392],
#      [0.000544984373971,0.0218416287489,0.0171017898361,0.0171689905565]]
y=[[7.8853059209,8.1838687846,10.886134227,7.31515756652,7.65745911846],
  [7.8015713855,8.39129537153,7.52960424043,7.22430472401,7.78282398775],
  [7.15165344992,7.3438076852,11.8272009709,6.71844834332,6.71676840734],
  [8.15468885654,6.49054208123,5.79387153139,7.61526245477,7.42629783858],
  [8.63817057907,8.09163497136,7.56945070049,7.54104966439]]

y = [map(lambda x: 1000*x, el) for el in y]
    
#here are old drag energy values for free channel, delete after done..
# [2.54731008612,1.52608656469,2.78558680355,1.42638075052,3.23267274691]
# x = [[4]*5,[6]*5,[8]*5,[10]*5, [14]*4]
x = [[-1]*4,[0]*5,[1]*5,[2]*5,[3]*5]
# my_xticks = ["4","6","8","10","14"]
my_xticks=["free","0","1", "2", "3"]
y = reduce(lambda a,b: a+b, y)
x = reduce(lambda a,b: a+b, x)
# print my_xticks
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(x,y,s=100)
# ax.set_xticks((4,6,8,10,12))
ax.set_xticks((-1,0,1,2,3))
ax.set_xticklabels(my_xticks)

ax.tick_params(axis='both', which='both', labelsize=20)
# ax.ylabel('Drag Energy (mJ)')
# ax.xlabel('Channel Width (cm)')
# ax.spines['left'].set_position('zero')
# ax.set_xlim(xmin=0)
ax.set_ylim(ymin=5000)
ax.set_xlim(xmin=-1.3, xmax=3.3)

ax.xaxis.grid(True)
fig.set_size_inches((6,4))
xfont = {'fontname':'Times New Roman'}
ax.set_xlabel("Deflection (cm)",fontdict=xfont, fontsize=20)
ax.set_ylabel("Electrical Energy (mJ)",fontdict=xfont,fontsize=20)
fig.savefig("elec_energy_deflection_plot.jpg", dpi=450, bbox_inches='tight')
# fig.set_size_inches(,)
plt.show()
# ax.show()

# %%
y=[[7.8853059209,8.1838687846,10.886134227,7.31515756652],
  [7.65745911846, 7.8015713855,8.39129537153,7.52960424043,7.22430472401],
  [7.78282398775, 7.15165344992,7.3438076852,11.8272009709,6.71844834332],
  [6.71676840734, 8.15468885654,6.49054208123,5.79387153139,7.61526245477],
  [7.42629783858, 8.63817057907,8.09163497136,7.56945070049,7.54104966439]]
y = [map(lambda x: 1000*x, el) for el in y]
y_index_map = ["free", "0", "1", "2", "3"]

df = pd.DataFrame(columns=["Deflection", "Value"])
i = 0
for j in xrange(len(y)):
    for v in y[j]:
        df.loc[i] = [y_index_map[j], v]
        i += 1

df["Value"] = pd.to_numeric(df["Value"])

# %%
xfont = {'fontname':'Times New Roman'}
ax = sns.boxplot(x="Deflection", y="Value", data=df, palette="hls")
ax.tick_params(axis='both', which='both', labelsize=24)
ax.set_ylabel("Electrical energy (mJ)",fontdict=xfont, fontsize=24)
ax.set_xlabel("Deflection (cm)",fontdict=xfont,fontsize=24)
ax.xaxis.grid(True)
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.arange(5000, end, 1000))

# %%
# y2=[[8.63817057907,8.09163497136,7.56945070049,7.54104966439],
#    [8.15468885654,6.49054208123,5.79387153139,7.61526245477,7.42629783858],
#    [7.15165344992,7.3438076852,11.8272009709,6.71844834332,6.71676840734],
#    [7.8015713855,8.39129537153,7.52960424043,7.22430472401,7.78282398775],
#    [7.8853059209,8.1838687846,10.886134227,7.31515756652,7.65745911846]]
# y2 = [map(lambda x: 1000*x, el) for el in y2]
# y2_index_map = ["free", "0", "1", "2", "3"]

# df2 = pd.DataFrame(columns=["Deflection", "Value"])
# i = 0
# for j in xrange(len(y2)):
#     for v in y2[j]:
#         df2.loc[i] = [y2_index_map[j], v]
#         i += 1

# df2["Value"] = pd.to_numeric(df2["Value"])

# %%
# xfont = {'fontname':'Times New Roman'}
# ax2 = sns.boxplot(x="Deflection", y="Value", data=df2, palette="hls")
# ax2.tick_params(axis='both', which='both', labelsize=24)
# ax2.set_ylabel("Electrical Energy (mJ)",fontdict=xfont, fontsize=24)
# ax2.set_xlabel("Deflection (cm)",fontdict=xfont,fontsize=24)
# ax2.xaxis.grid(True)
# start, end = ax2.get_ylim()
# ax2.yaxis.set_ticks(np.arange(5000, end, 1000))
