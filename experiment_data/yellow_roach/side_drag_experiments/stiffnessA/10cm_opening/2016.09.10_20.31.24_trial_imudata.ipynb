# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys
sys.path.append('../../../../../')
import utils

# %%
CALIBRATION_FILE = '../../../../../calibration/out/C.mat'
DATA_FILE = '../../../../../experiment_data/yellow_roach/side_drag_experiments/stiffnessA/10cm_opening/2016.09.10_20.31.24_trial_imudata.txt'

# %%
utils.print_header(DATA_FILE)
# Out:
# %  Data file recorded 2016/9/10  20:31:24
# %  Stride Frequency         = [1, 1]
# %  Lead In /Lead Out        =
# %  Deltas (Fractional)      = [0.25, 0.25, 0.25],[0.25, 0.25, 0.25]
# %  Phase                    = 32768
# %  Experiment.py
# %  Motor Gains    = [5000, 400, 200, 0, 300, 5000, 400, 200, 0, 300]

# %%
df = utils.process_data_files(DATA_FILE, CALIBRATION_FILE)
utils.plot_columns(df, [['TorqueL', 'TorqueR'], ['Left Leg Pos', 'Right Leg Pos'], ['RBEMF', 'LBEMF'], ['VMotorR', 'VMotorL'], ['PowerR', 'PowerL'], 'VBatt', 'AngleZ'], display=True, save_figure=False)

# %%
utils.plot_columns(df, [['Fx', 'Fy', 'Fz'], 'F_mag', ['Mx', 'My', 'Mz'], 'M_mag', ['AX', 'AY', 'AZ'], 'A_mag', ['GyroX', 'GyroY', 'GyroZ'], 'Gyro_mag'], display=True, save_figure=False)

# %%
df.plot(x='time', y=['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8'])

# %%
print "Here is the cost of transport for inside flaps"
cot = utils.cost_of_transport_inside_flaps(df, has_bottom_shell=False, v_avg=0.06773333333,
                                           start_time=23000, end_time=26000)
print cot
# Out:
# Here is the cost of transport for inside flaps
# nan
# /Users/Can/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
print df["PowerR"]
# Out:
# 0       3.816576
# 1       3.996842
# 2       3.890803
# 3       3.869596
# 4       4.007446
# 5       3.943822
# 6       3.860379
# 7       4.018049
# 8       3.816576
# 9       4.007446
# 10      3.816576
# 11      4.007446
# 12      3.816576
# 13      4.018049
# 14      3.816576
# 15      4.007446
# 16      3.818014
# 17      4.007446
# 18      3.881562
# 19      3.934519
# 20      3.923927
# 21      3.848388
# 22      3.954426
# 23      3.912011
# 24      3.986238
# 25      3.869596
# 26      3.922615
# 27      3.933219
# 28      3.848388
# 29      4.007446
#           ...
# 8370    1.570061
# 8371    1.640111
# 8372    1.549376
# 8373    1.662241
# 8374    1.689948
# 8375    1.720902
# 8376    1.670244
# 8377    1.693513
# 8378    1.640988
# 8379    1.630180
# 8380    1.645310
# 8381    1.676312
# 8382    1.637848
# 8383    1.691748
# 8384    1.744674
# 8385    1.764348
# 8386    1.376806
# 8387    1.797970
# 8388    1.761253
# 8389    1.551740
# 8390    1.673262
# 8391    1.734381
# 8392    1.624034
# 8393    1.694204
# 8394    1.659373
# 8395    1.904137
# 8396    1.605390
# 8397    1.592514
# 8398    1.584273
# 8399    1.657263
# Name: PowerR, dtype: float64
