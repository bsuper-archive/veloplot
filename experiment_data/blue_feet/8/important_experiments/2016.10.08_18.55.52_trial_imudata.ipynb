# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys
sys.path.append('../../../')
import utils

# %%
CALIBRATION_FILE = '../../../calibration/out/C.mat'
DATA_FILE = '../../../experiment_data/blue_feet/8/2016.10.08_18.55.52_trial_imudata.txt'

# %%
utils.print_header(DATA_FILE)
# Out:
# %  Data file recorded 2016/10/8  18:55:52
# %  Stride Frequency         = [1, 1]
# %  Lead In /Lead Out        =
# %  Deltas (Fractional)      = [0.25, 0.25, 0.25],[0.25, 0.25, 0.25]
# %  Phase                    = 32768
# %  Experiment.py
# %  Motor Gains    = [5000, 400, 200, 0, 300, 5000, 400, 200, 0, 300]

# %%
df = utils.process_data_files(DATA_FILE, CALIBRATION_FILE)
utils.plot_columns(df, [['TorqueL', 'TorqueR'], ['Left Leg Pos', 'Right Leg Pos'], ['RBEMF', 'LBEMF'], ['VMotorR', 'VMotorL'], ['PowerR', 'PowerL'], 'VBatt', 'AngleZ'], display=True, save_figure=False)

# %%
utils.plot_columns(df, [['Fx', 'Fy', 'Fz'], 'F_mag', ['Mx', 'My', 'Mz'], 'M_mag', ['AX', 'AY', 'AZ'], 'A_mag', ['GyroX', 'GyroY', 'GyroZ'], 'Gyro_mag'], display=True, save_figure=False)

# %%
df.plot(x='time', y=['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8'])

# %%
print "Here is the cost of transport for inside flaps"
cot = utils.cost_of_transport_inside_flaps(df, has_bottom_shell=False, v_avg=5.842,
                                           start_time=3000, end_time=9950, same_power_across_experiments=0,isCm=True)
print cot
# Out:
# Here is the cost of transport for inside flaps
# power:1.70117131369
# 40.5099631269

# %%
drag = utils.calculate_drag_energy(df, has_bottom_shell=False,start_time=3000,end_time=9950)
print drag
# Out:
# drag energy (kg*cm^2/s^2): 75.3230578126
# 0.00753230578126

# %%
electrical_energy = utils.calculate_electrical_energy(df, start_time=3000, end_time=9950)
# Out:
# electrical energy (Joules): 11.8231406302

# %%
electrical_energy_cont = utils.calculate_electrical_energy_cont(df, start_time=3000,end_time=9950)
# Out:
# electrical energy cont: 11.8272009709

# %%
import numpy as np
start = df['Right Leg Pos'][3000:3500].argmax()
end = df['Right Leg Pos'][8000:10000].argmax()
print start, end
print df['Right Leg Pos'][start]
print df['Right Leg Pos'][end]
starts = np.arange(start, end, step=1000)
ends = np.arange(start+1000, end+1000, step=1000)
intervals = np.vstack((starts, ends)).T
print intervals
# Out:
# 3499 8726
# 5.01573386966
# 6.27973429696
# [[3499 4499]
#  [4499 5499]
#  [5499 6499]
#  [6499 7499]
#  [7499 8499]
#  [8499 9499]]

# %%
drags = utils.get_drag_energy_from_list(df, False,intervals)
# Out:
# drag energy (kg*cm^2/s^2): 22.3136636211
# drag energy (kg*cm^2/s^2): 18.8437355377
# drag energy (kg*cm^2/s^2): 2.78127007301
# drag energy (kg*cm^2/s^2): 34.2134111268
# drag energy (kg*cm^2/s^2): 11.6720652952
# drag energy (kg*cm^2/s^2): 8.33323088804
