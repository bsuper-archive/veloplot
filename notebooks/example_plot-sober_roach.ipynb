# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys
sys.path.append('../')
import utils

# %%
CALIBRATION_FILE = "../calibration/out/C.mat"
DATA_FILE = "../experiment_data/sober_roach/2016.07.16_19.52.43_trial_imudata.txt"

utils.print_header(DATA_FILE)
# Out:
# %  Data file recorded 2016/7/16  19:52:43
# %  Stride Frequency         = [1, 1]
# %  Lead In /Lead Out        =
# %  Deltas (Fractional)      = [0.25, 0.25, 0.25],[0.25, 0.25, 0.25]
# %  Phase                    = 32768
# %  Experiment.py
# %  Motor Gains    = [5000, 400, 200, 0, 300, 5000, 400, 200, 0, 300]

# %%
df = utils.process_data_files(DATA_FILE, CALIBRATION_FILE)
utils.plot_columns(df, [["TorqueL", "TorqueR"], ["Left Leg Pos", "Right Leg Pos"], 
                        ["RBEMF", "LBEMF"], ["VMotorR", "VMotorL"], ["PowerR", "PowerL"], "VBatt", "AngleZ"],
                           display=True, save_figure=False, output_filename="basic.png")
# Out:
# Index([u'time', u'Right Leg Pos', u'Left Leg Pos', u'Commanded Right Leg Pos',
#        u'Commanded Left Leg Pos', u'DCR', u'DCL', u'GyroX', u'GyroY', u'GyroZ',
#        u'AX', u'AY', u'AZ', u'RBEMF', u'LBEMF', u'VBatt', u'S1', u'S2', u'S3',
#        u'S4', u'S5', u'S6', u'S7', u'S8'],
#       dtype='object')

# %%
utils.plot_columns(df, [["Fx", "Fy", "Fz"], "F_mag", ["Mx", "My", "Mz"], "M_mag", 
                        ["AX", "AY", "AZ"], "A_mag", ["GyroX", "GyroY", "GyroZ"], "Gyro_mag"], 
                           display=True, save_figure=False, output_filename="FMAG.png")
