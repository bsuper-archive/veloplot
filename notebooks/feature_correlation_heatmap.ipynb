# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys
sys.path.append('../')
import classify
import featurizer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
sns.set_palette("bright")

# %%
train_data, _, _ = classify.get_preprocessed_train_data()
df = pd.DataFrame(dict(zip(featurizer.get_feature_names(), train_data.T)))
corrmat = df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corrmat, vmax=.8, square=True)
plt.tight_layout()
plt.show()
# Out:
# CTL size: 149 ACT size: 132
