# %%
import sys
sys.path.append('../../')
import classify

DATA_FOLDER = "../../input/both_sides_4-18/"
CTL_FILES = DATA_FOLDER + "ctl*.csv" # No touch data
ACT_FILES = DATA_FOLDER + "act*.csv" # Touch data

# %%
classify.do_random_forests_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# ../../input/both_sides_4-18/ctl*.csv
#
# Running Random Forests...
# CTL size: 70 ACT size: 40
# 10-fold CV Acc Mean:  0.890909090909
# CV Scores:  0.909090909091, 0.818181818182, 0.727272727273, 1.0, 1.0, 0.909090909091, 0.909090909091, 0.727272727273, 0.909090909091, 1.0
# OOB score: 0.909090909091
# Feature Importances:
# ('Fx_entropy', 0.094625381988697632)
# ('My_max', 0.0868383507583977)
# ('Fx_max', 0.07366803563567817)
# ('Mx_mean', 0.04259628746514002)
# ('F_mag_entropy', 0.040862768838542785)
# ('Fx_std', 0.039985839051178432)
# ('My_entropy', 0.03845280221389881)
# ('Fy_max', 0.03025728823656184)
# ('My_mean', 0.027813526780505228)
# ('F_mag_min', 0.024582228738449757)
# ("('Mx', 'My')_corre", 0.023056927294787435)
# ('Mx_min', 0.022226913192154373)
# ('Fy_entropy', 0.020856282437336136)
# ('F_mag_mean', 0.018185528767214919)
# ('Fy_mean', 0.017777587224172903)
# ("('Fx', 'Fy')_corre", 0.016185808186077059)
# ('Fx_energy', 0.012241479646544963)
# ...

# %%
classify.do_xgb_trees_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running XGB Trees...
# CTL size: 70 ACT size: 40
# 10-fold CV Acc Mean:  0.890909090909
# CV Scores:  0.909090909091, 0.909090909091, 0.909090909091, 0.818181818182, 0.909090909091, 1.0, 0.909090909091, 0.818181818182, 0.818181818182, 0.909090909091
# Feature Importances:
# ('Fx_max', 0.027833163139107647)
# ('Fx_entropy', 0.027033112179068862)
# ('F_mag_entropy', 0.023582022956827067)
# ('Fx_energy', 0.022623906809947608)
# ('My_skew', 0.021602993180510462)
# ('M_mag_min', 0.0213767182236244)
# ('My_std', 0.016087735538617576)
# ('Mx_mean', 0.014927603827373516)
# ('AX_skew', 0.014863874297027702)
# ('A_mag_max', 0.014645027904015718)
# ('M_mag_skew', 0.013868619083417582)
# ('AY_entropy', 0.013349686697869911)
# ("('Fx', 'Fy')_corre", 0.013329798232770022)
# ('Fy_entropy', 0.013263616598815992)
# ('My_mean', 0.013166301875929202)
# ('Mx_min', 0.013092097313286376)
# ('AX_entropy', 0.012208514612933161)
# ('AZ_min', 0.012132224266683473)
# ('Fz_kurtosis', 0.011780847590633154)
# ...

# %%
classify.do_svc_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running SVC...
# CTL size: 70 ACT size: 40
# 10-fold CV Acc Mean:  0.927272727273
# CV Scores:  0.818181818182, 0.909090909091, 1.0, 1.0, 0.818181818182, 1.0, 0.909090909091, 1.0, 0.909090909091, 0.909090909091
# (SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  StandardScaler(copy=True, with_mean=True, with_std=True))

# %%
classify.do_dnn_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running Neural Network...
# CTL size: 70 ACT size: 40
# Step #1, epoch #1, avg. loss: 1.12931
# Step #201, epoch #201, avg. loss: 0.05250
# Step #401, epoch #401, avg. loss: 0.00301
# Step #601, epoch #601, avg. loss: 0.00133
# Step #801, epoch #801, avg. loss: 0.00082
# Step #1001, epoch #1001, avg. loss: 0.00058
# Step #1201, epoch #1201, avg. loss: 0.00044
# Step #1401, epoch #1401, avg. loss: 0.00035
# Step #1601, epoch #1601, avg. loss: 0.00029
# Step #1801, epoch #1801, avg. loss: 0.00025
# Step #1, epoch #1, avg. loss: 1.20903
# Step #201, epoch #201, avg. loss: 0.05557
# Step #401, epoch #401, avg. loss: 0.00360
# Step #601, epoch #601, avg. loss: 0.00157
# Step #801, epoch #801, avg. loss: 0.00095
# Step #1001, epoch #1001, avg. loss: 0.00066
# Step #1201, epoch #1201, avg. loss: 0.00050
# Step #1401, epoch #1401, avg. loss: 0.00040
# Step #1601, epoch #1601, avg. loss: 0.00033
# Step #1801, epoch #1801, avg. loss: 0.00028
# Step #1, epoch #1, avg. loss: 1.17156
# ...

# %%
classify.do_ensemble_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running Ensemble Cross Val...
# CTL size: 70 ACT size: 40
# Step #1, epoch #1, avg. loss: 1.17943
# Step #201, epoch #201, avg. loss: 0.04672
# Step #401, epoch #401, avg. loss: 0.00283
# Step #601, epoch #601, avg. loss: 0.00128
# Step #801, epoch #801, avg. loss: 0.00079
# Step #1001, epoch #1001, avg. loss: 0.00055
# Step #1201, epoch #1201, avg. loss: 0.00042
# Step #1401, epoch #1401, avg. loss: 0.00034
# Step #1601, epoch #1601, avg. loss: 0.00028
# Step #1801, epoch #1801, avg. loss: 0.00024
# Step #1, epoch #1, avg. loss: 1.17421
# Step #201, epoch #201, avg. loss: 0.05076
# Step #401, epoch #401, avg. loss: 0.00278
# Step #601, epoch #601, avg. loss: 0.00123
# Step #801, epoch #801, avg. loss: 0.00075
# Step #1001, epoch #1001, avg. loss: 0.00053
# Step #1201, epoch #1201, avg. loss: 0.00040
# Step #1401, epoch #1401, avg. loss: 0.00032
# Step #1601, epoch #1601, avg. loss: 0.00026
# Step #1801, epoch #1801, avg. loss: 0.00022
# Step #1, epoch #1, avg. loss: 1.16588
# ...
