# %%
import sys
sys.path.append('../../')
import classify

DATA_FOLDER = "../../input/both_sides_4-18/"
CTL_FILES = DATA_FOLDER + "ctl*.csv" # No touch data
ACT_FILES = DATA_FOLDER + "act*.csv" # Touch data

# %%
classify.do_random_forests_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# ../../input/both_sides_4-18/ctl*.csv
#
# Running Random Forests...
# CTL size: 78 ACT size: 47
# 10-fold CV Acc Mean:  0.898601398601
# CV Scores:  0.923076923077, 0.923076923077, 0.923076923077, 0.923076923077, 1.0, 0.692307692308, 0.692307692308, 1.0, 0.909090909091, 1.0
# OOB score: 0.896
# Feature Importances:
# ('Fx_entropy', 0.11322530241390918)
# ('F_mag_entropy', 0.068943038184094904)
# ('My_entropy', 0.068068167969550689)
# ('Fx_max', 0.067708046179964093)
# ('Fx_std', 0.04929114342493654)
# ('My_mean', 0.04597142944208641)
# ('My_max', 0.045950092206339194)
# ('Mx_mean', 0.039112074996038318)
# ('F_mag_min', 0.039030878359253736)
# ("('Fx', 'Fy')_corre", 0.034036741171505985)
# ("('Mx', 'My')_corre", 0.032900843750113602)
# ('Fx_energy', 0.028342059511451793)
# ('Mx_min', 0.021554400975705969)
# ('Fy_max', 0.020269111110359322)
# ('Fx_mean', 0.017551227407916106)
# ("('My', 'Mz')_corre", 0.01594463475591645)
# ('Fy_entropy', 0.014653964264460388)
# ('M_mag_kurtosis', 0.012451173449450617)
# ('F_mag_mean', 0.012420487290523384)
# ('Fy_mean', 0.011444295933095433)
# ('Fz_std', 0.011250702280669531)
# ('Fz_min', 0.010605737885342956)
# ('M_mag_min', 0.010244618963573046)
# ('Fy_energy', 0.0099508379661351221)
# ('Fy_std', 0.0088952071748368312)
# ('My_kurtosis', 0.0083102771040070682)
# ('M_mag_mean', 0.0083025136574825052)
# ('Mx_energy', 0.0082097289835572785)
# ('Mz_skew', 0.007973627777409318)
# ('M_mag_skew', 0.0079321382530142277)
# ('My_skew', 0.0075344083162950347)
# ('My_std', 0.0074395020594713191)
# ('My_energy', 0.0070146178235538361)
# ('Mz_min', 0.006761201187662479)
# ('F_mag_energy', 0.0066644498502225358)
# ('M_mag_entropy', 0.0055112212945066718)
# ('Fx_kurtosis', 0.0048431825250462371)
# ('M_mag_max', 0.0046297289697368495)
# ('M_mag_std', 0.0046250353043925966)
# ('Mz_mean', 0.0043798971259532467)
# ('F_mag_std', 0.0042751711145311627)
# ('My_min', 0.0041893251513192356)
# ('F_mag_skew', 0.0040429449177865843)
# ('Fx_min', 0.0039854021520207379)
# ("('Mx', 'Mz')_corre", 0.0039710847421857067)
# ('Mx_skew', 0.0039220224559340733)
# ('M_mag_energy', 0.003735105481972617)
# ('F_mag_kurtosis', 0.0036677665447172902)
# ('Mx_max', 0.0036507123830871978)
# ('Fz_kurtosis', 0.0036020608646829839)
# ('Mz_kurtosis', 0.0035893534058139402)
# ('Mx_entropy', 0.0035658123640039808)
# ('Mx_std', 0.0035368574471076352)
# ('Fy_min', 0.0033646632592047353)
# ('Mz_energy', 0.0033077689275772134)
# ('Fx_skew', 0.0029434591586399044)
# ('Fy_skew', 0.0029366517379815953)
# ('Fz_energy', 0.0027881902079185598)
# ('Fz_mean', 0.0027072960820661534)
# ("('Fy', 'Fz')_corre", 0.0026775014771303006)
# ('Mz_entropy', 0.0024641128227549892)
# ("('Fx', 'Fz')_corre", 0.0024053483140206301)
# ('Mz_std', 0.0023504303332766811)
# ('F_mag_max', 0.0021390263698893431)
# ('Mx_kurtosis', 0.0019970318624336399)
# ('Fz_skew', 0.0019313903640049599)
# ('Mz_max', 0.0019082626496071526)
# ('Fy_kurtosis', 0.0018229536379724184)
# ('Fz_max', 0.0017553396970302196)
# ('Fz_entropy', 0.00081920677378757465)
# (RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#              oob_score=True, random_state=None, verbose=0, warm_start=False),
#  StandardScaler(copy=True, with_mean=True, with_std=True))

# %%
classify.do_xgb_trees_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running XGB Trees...
# CTL size: 78 ACT size: 47
# 10-fold CV Acc Mean:  0.904254079254
# CV Scores:  0.923076923077, 0.923076923077, 1.0, 0.846153846154, 0.846153846154, 0.846153846154, 0.923076923077, 0.916666666667, 0.909090909091, 0.909090909091
# Feature Importances:
# ('M_mag_min', 0.047739764096607171)
# ('Fx_entropy', 0.044083538556840773)
# ('My_skew', 0.034414820723048779)
# ('F_mag_entropy', 0.032673273324407344)
# ('My_max', 0.029497368426987299)
# ('Fx_energy', 0.027078971175844138)
# ('Fz_min', 0.025965752694979506)
# ('My_std', 0.02306478665329971)
# ('Fx_max', 0.021904994798894205)
# ('M_mag_kurtosis', 0.021129774050433165)
# ('Fx_kurtosis', 0.019942666072493887)
# ('Mx_min', 0.019913253765986069)
# ("('Mx', 'My')_corre", 0.018930152832489954)
# ('My_kurtosis', 0.018498410735425033)
# ('Fz_std', 0.018449859194159614)
# ('Fy_mean', 0.016310087921507975)
# ('My_energy', 0.015741080194388052)
# ('Fx_mean', 0.015199532732744785)
# ("('Fx', 'Fy')_corre", 0.014678270800195035)
# ('My_mean', 0.013740023051673189)
# ('Fy_max', 0.01347687697819926)
# ('Mx_energy', 0.012991662699085482)
# ('Mz_min', 0.01299047958650023)
# ('Mx_mean', 0.012748837393893668)
# ('Fy_std', 0.012733495270802293)
# ('F_mag_min', 0.012518658183731192)
# ('Mx_std', 0.012157133868427034)
# ('My_min', 0.011882099177147705)
# ('F_mag_kurtosis', 0.011651863200790268)
# ('Fx_min', 0.011439968291114256)
# ('Fx_std', 0.010903694797084114)
# ('My_entropy', 0.010244114181846958)
# ('F_mag_std', 0.0096893222767090777)
# ('F_mag_max', 0.0096311054417022677)
# ('Fy_min', 0.0096088916362471761)
# ('M_mag_skew', 0.009217857907344626)
# ('F_mag_skew', 0.0090527350290408176)
# ('Mx_kurtosis', 0.0086756519689130604)
# ('Fz_energy', 0.0084967506893242287)
# ('Mz_skew', 0.0083694899802502724)
# ('Fy_entropy', 0.0078716810618299667)
# ('Fy_energy', 0.0071636342809134031)
# ('Fz_max', 0.00672020955860994)
# ('Mz_energy', 0.0067103459302751091)
# ('Mz_entropy', 0.0065303882774671376)
# ('Mz_mean', 0.0064645487579872421)
# ('M_mag_mean', 0.0061006154852418781)
# ('M_mag_entropy', 0.0059102638864455539)
# ('Fy_kurtosis', 0.0058785073207794324)
# ('M_mag_std', 0.0057225124185243774)
# ('F_mag_mean', 0.005422710508565555)
# ("('Fy', 'Fz')_corre", 0.0050055505672178049)
# ('Fx_skew', 0.0048318077883987799)
# ('Fy_skew', 0.004773526363198605)
# ('Mz_max', 0.0046611501558883398)
# ('Mx_max', 0.0045461753149856352)
# ('Mx_skew', 0.0042974359482866467)
# ('Mz_std', 0.0037941008462467158)
# ("('My', 'Mz')_corre", 0.0037857409371817841)
# ('M_mag_max', 0.0036589573740018972)
# ('Fz_kurtosis', 0.0035109616910360699)
# ('Fz_entropy', 0.0031533223160594283)
# ("('Fx', 'Fz')_corre", 0.0029827500826619347)
# ('Fz_mean', 0.0028511603789029959)
# ('Mx_entropy', 0.0024392444444016033)
# ('F_mag_energy', 0.0020775419909632954)
# ('M_mag_energy', 0.002073519630321435)
# ('Mz_kurtosis', 0.0015517112087772296)
# ('Fz_skew', 0.0012012221636910369)
# ("('Mx', 'Mz')_corre", 0.00087163295057952515)
# (GradientBoostingClassifier(init=None, learning_rate=0.1, loss='deviance',
#                max_depth=3, max_features='sqrt', max_leaf_nodes=None,
#                min_samples_leaf=1, min_samples_split=2,
#                min_weight_fraction_leaf=0.0, n_estimators=200,
#                presort='auto', random_state=None, subsample=1.0, verbose=0,
#                warm_start=False),
#  StandardScaler(copy=True, with_mean=True, with_std=True))

# %%
classify.do_svc_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running SVC...
# CTL size: 78 ACT size: 47
# 10-fold CV Acc Mean:  0.909906759907
# CV Scores:  1.0, 1.0, 0.769230769231, 0.923076923077, 0.923076923077, 0.923076923077, 1.0, 0.833333333333, 0.909090909091, 0.818181818182
# (SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  StandardScaler(copy=True, with_mean=True, with_std=True))

# %%
classify.do_dnn_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running Neural Network...
# CTL size: 78 ACT size: 47
# Step #1, avg. loss: 1.15090
# Step #201, epoch #100, avg. loss: 0.07327
# Step #401, epoch #200, avg. loss: 0.00487
# Step #601, epoch #300, avg. loss: 0.00205
# Step #801, epoch #400, avg. loss: 0.00125
# Step #1001, epoch #500, avg. loss: 0.00088
# Step #1201, epoch #600, avg. loss: 0.00061
# Step #1401, epoch #700, avg. loss: 0.00050
# Step #1601, epoch #800, avg. loss: 0.00042
# Step #1801, epoch #900, avg. loss: 0.00034
# Step #1, avg. loss: 1.16132
# Step #201, epoch #100, avg. loss: 0.06570
# Step #401, epoch #200, avg. loss: 0.00466
# Step #601, epoch #300, avg. loss: 0.00196
# Step #801, epoch #400, avg. loss: 0.00124
# Step #1001, epoch #500, avg. loss: 0.00084
# Step #1201, epoch #600, avg. loss: 0.00062
# Step #1401, epoch #700, avg. loss: 0.00052
# Step #1601, epoch #800, avg. loss: 0.00042
# Step #1801, epoch #900, avg. loss: 0.00035
# Step #1, avg. loss: 1.07176
# Step #201, epoch #100, avg. loss: 0.06341
# Step #401, epoch #200, avg. loss: 0.00472
# Step #601, epoch #300, avg. loss: 0.00190
# Step #801, epoch #400, avg. loss: 0.00120
# Step #1001, epoch #500, avg. loss: 0.00079
# Step #1201, epoch #600, avg. loss: 0.00060
# Step #1401, epoch #700, avg. loss: 0.00049
# Step #1601, epoch #800, avg. loss: 0.00039
# Step #1801, epoch #900, avg. loss: 0.00033
# Step #1, avg. loss: 1.07881
# Step #201, epoch #100, avg. loss: 0.07412
# Step #401, epoch #200, avg. loss: 0.00513
# Step #601, epoch #300, avg. loss: 0.00210
# Step #801, epoch #400, avg. loss: 0.00134
# Step #1001, epoch #500, avg. loss: 0.00092
# Step #1201, epoch #600, avg. loss: 0.00064
# Step #1401, epoch #700, avg. loss: 0.00052
# Step #1601, epoch #800, avg. loss: 0.00043
# Step #1801, epoch #900, avg. loss: 0.00035
# Step #1, avg. loss: 1.12756
# Step #201, epoch #100, avg. loss: 0.06372
# Step #401, epoch #200, avg. loss: 0.00467
# Step #601, epoch #300, avg. loss: 0.00205
# Step #801, epoch #400, avg. loss: 0.00124
# Step #1001, epoch #500, avg. loss: 0.00086
# Step #1201, epoch #600, avg. loss: 0.00060
# Step #1401, epoch #700, avg. loss: 0.00050
# Step #1601, epoch #800, avg. loss: 0.00039
# Step #1801, epoch #900, avg. loss: 0.00031
# Step #1, avg. loss: 1.16438
# Step #201, epoch #100, avg. loss: 0.05660
# Step #401, epoch #200, avg. loss: 0.00409
# Step #601, epoch #300, avg. loss: 0.00169
# Step #801, epoch #400, avg. loss: 0.00104
# Step #1001, epoch #500, avg. loss: 0.00073
# Step #1201, epoch #600, avg. loss: 0.00054
# Step #1401, epoch #700, avg. loss: 0.00044
# Step #1601, epoch #800, avg. loss: 0.00034
# Step #1801, epoch #900, avg. loss: 0.00028
# Step #1, avg. loss: 1.10788
# Step #201, epoch #100, avg. loss: 0.07254
# Step #401, epoch #200, avg. loss: 0.00560
# Step #601, epoch #300, avg. loss: 0.00213
# Step #801, epoch #400, avg. loss: 0.00134
# Step #1001, epoch #500, avg. loss: 0.00092
# Step #1201, epoch #600, avg. loss: 0.00063
# Step #1401, epoch #700, avg. loss: 0.00052
# Step #1601, epoch #800, avg. loss: 0.00042
# Step #1801, epoch #900, avg. loss: 0.00034
# Step #1, avg. loss: 1.11322
# Step #201, epoch #100, avg. loss: 0.07284
# Step #401, epoch #200, avg. loss: 0.00496
# Step #601, epoch #300, avg. loss: 0.00210
# Step #801, epoch #400, avg. loss: 0.00129
# Step #1001, epoch #500, avg. loss: 0.00089
# Step #1201, epoch #600, avg. loss: 0.00064
# Step #1401, epoch #700, avg. loss: 0.00053
# Step #1601, epoch #800, avg. loss: 0.00043
# Step #1801, epoch #900, avg. loss: 0.00035
# Step #1, avg. loss: 1.09421
# Step #201, epoch #100, avg. loss: 0.07297
# Step #401, epoch #200, avg. loss: 0.00532
# Step #601, epoch #300, avg. loss: 0.00214
# Step #801, epoch #400, avg. loss: 0.00126
# Step #1001, epoch #500, avg. loss: 0.00086
# Step #1201, epoch #600, avg. loss: 0.00065
# Step #1401, epoch #700, avg. loss: 0.00052
# Step #1601, epoch #800, avg. loss: 0.00042
# Step #1801, epoch #900, avg. loss: 0.00035
# Step #1, avg. loss: 1.19368
# Step #201, epoch #100, avg. loss: 0.06372
# Step #401, epoch #200, avg. loss: 0.00506
# Step #601, epoch #300, avg. loss: 0.00190
# Step #801, epoch #400, avg. loss: 0.00126
# Step #1001, epoch #500, avg. loss: 0.00088
# Step #1201, epoch #600, avg. loss: 0.00058
# Step #1401, epoch #700, avg. loss: 0.00049
# Step #1601, epoch #800, avg. loss: 0.00039
# Step #1801, epoch #900, avg. loss: 0.00031
# 10-fold CV Acc Mean:  0.919871794872
# CV Scores:  1.0, 0.923076923077, 0.923076923077, 1.0, 0.769230769231, 0.75, 1.0, 1.0, 1.0, 0.833333333333
# /usr/local/lib/python2.7/site-packages/skflow/io/data_feeder.py:217: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   out.itemset((i, self.y[sample]), 1.0)
# (TensorFlowEstimator(batch_size=100, class_weight=None,
#            continue_training=False, early_stopping_rounds=None,
#            keep_checkpoint_every_n_hours=10000, learning_rate=0.1,
#            max_to_keep=5, model_fn=<function relu_dnn at 0x1054fea28>,
#            n_classes=2, num_cores=4, optimizer='SGD', steps=2000,
#            tf_master='', tf_random_seed=42, verbose=1),
#  StandardScaler(copy=True, with_mean=True, with_std=True))

# %%
classify.do_ensemble_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running Ensemble Cross Val...
# CTL size: 78 ACT size: 47
# Step #1, avg. loss: 1.11778
# Step #201, epoch #100, avg. loss: 0.07042
# Step #401, epoch #200, avg. loss: 0.00494
# Step #601, epoch #300, avg. loss: 0.00201
# Step #801, epoch #400, avg. loss: 0.00119
# Step #1001, epoch #500, avg. loss: 0.00086
# Step #1201, epoch #600, avg. loss: 0.00062
# Step #1401, epoch #700, avg. loss: 0.00049
# Step #1601, epoch #800, avg. loss: 0.00041
# Step #1801, epoch #900, avg. loss: 0.00035
# Step #1, avg. loss: 1.13413
# Step #201, epoch #100, avg. loss: 0.06568
# Step #401, epoch #200, avg. loss: 0.00469
# Step #601, epoch #300, avg. loss: 0.00200
# Step #801, epoch #400, avg. loss: 0.00125
# Step #1001, epoch #500, avg. loss: 0.00094
# Step #1201, epoch #600, avg. loss: 0.00064
# Step #1401, epoch #700, avg. loss: 0.00050
# Step #1601, epoch #800, avg. loss: 0.00041
# Step #1801, epoch #900, avg. loss: 0.00036
# Step #1, avg. loss: 1.12410
# Step #201, epoch #100, avg. loss: 0.06152
# Step #401, epoch #200, avg. loss: 0.00485
# Step #601, epoch #300, avg. loss: 0.00196
# Step #801, epoch #400, avg. loss: 0.00114
# Step #1001, epoch #500, avg. loss: 0.00081
# Step #1201, epoch #600, avg. loss: 0.00059
# Step #1401, epoch #700, avg. loss: 0.00047
# Step #1601, epoch #800, avg. loss: 0.00040
# Step #1801, epoch #900, avg. loss: 0.00032
# Step #1, avg. loss: 1.12552
# Step #201, epoch #100, avg. loss: 0.07148
# Step #401, epoch #200, avg. loss: 0.00557
# Step #601, epoch #300, avg. loss: 0.00228
# Step #801, epoch #400, avg. loss: 0.00129
# Step #1001, epoch #500, avg. loss: 0.00095
# Step #1201, epoch #600, avg. loss: 0.00067
# Step #1401, epoch #700, avg. loss: 0.00052
# Step #1601, epoch #800, avg. loss: 0.00042
# Step #1801, epoch #900, avg. loss: 0.00036
# Step #1, avg. loss: 1.16275
# Step #201, epoch #100, avg. loss: 0.06664
# Step #401, epoch #200, avg. loss: 0.00520
# Step #601, epoch #300, avg. loss: 0.00213
# Step #801, epoch #400, avg. loss: 0.00122
# Step #1001, epoch #500, avg. loss: 0.00086
# Step #1201, epoch #600, avg. loss: 0.00065
# Step #1401, epoch #700, avg. loss: 0.00053
# Step #1601, epoch #800, avg. loss: 0.00042
# Step #1801, epoch #900, avg. loss: 0.00036
# Step #1, avg. loss: 1.09583
# Step #201, epoch #100, avg. loss: 0.06657
# Step #401, epoch #200, avg. loss: 0.00447
# Step #601, epoch #300, avg. loss: 0.00179
# Step #801, epoch #400, avg. loss: 0.00106
# Step #1001, epoch #500, avg. loss: 0.00074
# Step #1201, epoch #600, avg. loss: 0.00058
# Step #1401, epoch #700, avg. loss: 0.00046
# Step #1601, epoch #800, avg. loss: 0.00037
# Step #1801, epoch #900, avg. loss: 0.00032
# Step #1, avg. loss: 1.20229
# Step #201, epoch #100, avg. loss: 0.07032
# Step #401, epoch #200, avg. loss: 0.00493
# Step #601, epoch #300, avg. loss: 0.00204
# Step #801, epoch #400, avg. loss: 0.00116
# Step #1001, epoch #500, avg. loss: 0.00089
# Step #1201, epoch #600, avg. loss: 0.00063
# Step #1401, epoch #700, avg. loss: 0.00048
# Step #1601, epoch #800, avg. loss: 0.00041
# Step #1801, epoch #900, avg. loss: 0.00035
# Step #1, avg. loss: 1.12920
# Step #201, epoch #100, avg. loss: 0.06362
# Step #401, epoch #200, avg. loss: 0.00525
# Step #601, epoch #300, avg. loss: 0.00198
# Step #801, epoch #400, avg. loss: 0.00123
# Step #1001, epoch #500, avg. loss: 0.00088
# Step #1201, epoch #600, avg. loss: 0.00070
# Step #1401, epoch #700, avg. loss: 0.00055
# Step #1601, epoch #800, avg. loss: 0.00044
# Step #1801, epoch #900, avg. loss: 0.00035
# Step #1, avg. loss: 1.11031
# Step #201, epoch #100, avg. loss: 0.07265
# Step #401, epoch #200, avg. loss: 0.00474
# Step #601, epoch #300, avg. loss: 0.00208
# Step #801, epoch #400, avg. loss: 0.00124
# Step #1001, epoch #500, avg. loss: 0.00082
# Step #1201, epoch #600, avg. loss: 0.00062
# Step #1401, epoch #700, avg. loss: 0.00052
# Step #1601, epoch #800, avg. loss: 0.00043
# Step #1801, epoch #900, avg. loss: 0.00036
# Step #1, avg. loss: 1.16567
# Step #201, epoch #100, avg. loss: 0.06392
# Step #401, epoch #200, avg. loss: 0.00460
# Step #601, epoch #300, avg. loss: 0.00186
# Step #801, epoch #400, avg. loss: 0.00107
# Step #1001, epoch #500, avg. loss: 0.00084
# Step #1201, epoch #600, avg. loss: 0.00058
# Step #1401, epoch #700, avg. loss: 0.00047
# Step #1601, epoch #800, avg. loss: 0.00040
# Step #1801, epoch #900, avg. loss: 0.00032
# 10-fold CV Acc Mean:  0.911538461538
# CV Scores:  0.923076923077, 0.923076923077, 0.923076923077, 0.923076923077, 0.923076923077, 0.916666666667, 0.916666666667, 0.833333333333, 1.0, 0.833333333333
# (VotingClassifier(estimators=[('dnn', TensorFlowEstimator(batch_size=100, class_weight=None,
#            continue_training=False, early_stopping_rounds=None,
#            keep_checkpoint_every_n_hours=10000, learning_rate=0.1,
#            max_to_keep=5, model_fn=<function relu_dnn at 0x10cb43c80>,
#            n_classes=2, num...',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False))],
#           voting='soft', weights=[1, 1, 1, 1]),
#  StandardScaler(copy=True, with_mean=True, with_std=True))
