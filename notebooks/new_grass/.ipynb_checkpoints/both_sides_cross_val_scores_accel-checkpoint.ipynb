# %%
import sys
sys.path.append('../../')
import classify

DATA_FOLDER = "../../input/both_sides_4-18/"
CTL_FILES = DATA_FOLDER + "ctl*.csv" # No touch data
ACT_FILES = DATA_FOLDER + "act*.csv" # Touch data

# %%
classify.do_random_forests_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# ../../input/both_sides_4-18/ctl*.csv
#
# Running Random Forests...
# CTL size: 70 ACT size: 40
# 10-fold CV Acc Mean:  0.909090909091
# CV Scores:  0.909090909091, 0.909090909091, 1.0, 0.909090909091, 0.909090909091, 0.818181818182, 1.0, 0.909090909091, 0.909090909091, 0.818181818182
# OOB score: 0.9
# Feature Importances:
# ('Fx_entropy', 0.085538037122108418)
# ('My_mean', 0.069855068137657905)
# ('Fx_max', 0.05825528733243452)
# ('Mx_mean', 0.047818876754673639)
# ("('Fx', 'Fy')_corre", 0.046081004446302531)
# ('F_mag_entropy', 0.044410323440266852)
# ('My_entropy', 0.043922623330212268)
# ("('Mx', 'My')_corre", 0.037634992104610535)
# ('Fy_max', 0.035431445241526728)
# ('Fx_std', 0.030938160342195847)
# ('My_max', 0.030275645800281293)
# ("('My', 'Mz')_corre", 0.025699481900984467)
# ('Fy_mean', 0.022076226968381279)
# ('Fy_energy', 0.021384977399032012)
# ('Fy_entropy', 0.019687880487639326)
# ('My_std', 0.018664010247581984)
# ('Fx_energy', 0.01786216337215903)
# ('AX_max', 0.01465949617363458)
# ('F_mag_min', 0.011805262538703683)
# ('Mx_min', 0.010671484045318985)
# ('M_mag_kurtosis', 0.010009713313119999)
# ('Fx_mean', 0.0096789087544254856)
# ('My_energy', 0.0091855066535939962)
# ('AZ_max', 0.0082283867752920084)
# ('A_mag_max', 0.0079358260459366139)
# ('F_mag_mean', 0.0077622111534016965)
# ('AX_mean', 0.0075018131531978515)
# ('AY_max', 0.007320474781951066)
# ('AY_min', 0.0072298622303585023)
# ('My_skew', 0.0070275589228828428)
# ('Mx_energy', 0.0069685558514729906)
# ('Fz_std', 0.0069422428933769154)
# ('AX_min', 0.006707249550730353)
# ('AZ_energy', 0.0066782982702393405)
# ('Fz_min', 0.0064559628140893012)
# ('M_mag_skew', 0.0064160645708335592)
# ('Fz_mean', 0.0057654274710753402)
# ('AY_energy', 0.0056336798544433363)
# ('Mx_entropy', 0.0055172422856119199)
# ('AZ_min', 0.0051347942612587306)
# ('F_mag_energy', 0.0049352899200338207)
# ('M_mag_min', 0.0049052990746366095)
# ('Fy_std', 0.0046493320161199846)
# ('Mz_min', 0.0046388255560082135)
# ('F_mag_kurtosis', 0.0045379354932543626)
# ('AZ_entropy', 0.0044811045484615666)
# ('AY_entropy', 0.004321816023787858)
# ('My_min', 0.0043198909004932232)
# ('Mz_skew', 0.0042085315762172533)
# ('AZ_std', 0.0040241995391647077)
# ('AX_entropy', 0.0038389632936300022)
# ('My_kurtosis', 0.0037973209609306387)
# ('A_mag_energy', 0.0036860114542449189)
# ('Fz_kurtosis', 0.0036828410913261837)
# ('M_mag_max', 0.0036457600459870792)
# ('AZ_skew', 0.0035711716974795621)
# ('Fz_energy', 0.0034786184253724661)
# ('AX_std', 0.0034412137234460911)
# ('M_mag_energy', 0.0033603705925966077)
# ('Fx_min', 0.0032191481629245556)
# ('AY_kurtosis', 0.0031884357315416756)
# ('F_mag_skew', 0.0031213440727896322)
# ('AZ_mean', 0.0030837906219472033)
# ('Mz_max', 0.0030381534536621626)
# ('AY_skew', 0.0030054983141651571)
# ('M_mag_mean', 0.0029317726451421749)
# ('Mx_max', 0.0028516726501412975)
# ("('Fx', 'Fz')_corre", 0.0027645998322275195)
# ('A_mag_std', 0.0027494447095570101)
# ('Fx_skew', 0.002724103223710625)
# ('AX_energy', 0.0026690032454055757)
# ('F_mag_std', 0.0026312126463271224)
# ('Fy_min', 0.0025838537600124385)
# ('A_mag_min', 0.0025823936601383946)
# ('Fy_skew', 0.0024811765329197243)
# ('Mz_mean', 0.0023347221500190341)
# ('AX_skew', 0.0022995679196323388)
# ('Mx_skew', 0.0021322691771735207)
# ('Fx_kurtosis', 0.0021010671699810326)
# ('Mz_entropy', 0.0019670641159763944)
# ("('Fy', 'Fz')_corre", 0.0017423970956019974)
# ('AZ_kurtosis', 0.0016004792752576115)
# ('Mx_std', 0.0015995668377664311)
# ('A_mag_skew', 0.0015623811249955925)
# ('Mz_energy', 0.0015263536773036793)
# ('AY_mean', 0.0015201612619753007)
# ('A_mag_mean', 0.0014426882945745953)
# ('A_mag_kurtosis', 0.0014336453387228316)
# ('Fz_max', 0.0013903603862456771)
# ('Mz_kurtosis', 0.0013430507007135672)
# ('Fz_entropy', 0.0013213769269944759)
# ("('Mx', 'Mz')_corre", 0.001292020155533686)
# ('AX_kurtosis', 0.0012843844356192665)
# ('Fz_skew', 0.0012829719278780417)
# ('AY_std', 0.001268165780959166)
# ('Fy_kurtosis', 0.0012296022150125241)
# ('F_mag_max', 0.0011983136443293047)
# ('A_mag_entropy', 0.001183726681631179)
# ('M_mag_std', 0.0011529595869029642)
# ('Mx_kurtosis', 0.0010457112210222911)
# ('Mz_std', 0.0009640002501328913)
# ('M_mag_entropy', 0.00085866665924346777)
# (RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#              oob_score=True, random_state=None, verbose=0, warm_start=False),
#  StandardScaler(copy=True, with_mean=True, with_std=True))

# %%
classify.do_xgb_trees_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running XGB Trees...
# CTL size: 70 ACT size: 40
# 10-fold CV Acc Mean:  0.909090909091
# CV Scores:  0.727272727273, 0.727272727273, 1.0, 0.818181818182, 0.909090909091, 1.0, 0.909090909091, 1.0, 1.0, 1.0
# Feature Importances:
# ('Fx_entropy', 0.034350432796426064)
# ('F_mag_entropy', 0.032101778635533831)
# ('M_mag_min', 0.026838457309474015)
# ('Mx_min', 0.021713715266852285)
# ('Fx_max', 0.017971202709602355)
# ('My_skew', 0.017290041336635292)
# ('AY_entropy', 0.017205753026826507)
# ('AX_min', 0.016626252098286498)
# ('Fx_energy', 0.016236317407601862)
# ('M_mag_kurtosis', 0.015073313325804454)
# ('Fy_energy', 0.014702288228588567)
# ('Mx_mean', 0.014204053337146402)
# ("('Fx', 'Fy')_corre", 0.014046247520220207)
# ('Fy_std', 0.013455986896395902)
# ('Fz_kurtosis', 0.013078042160959645)
# ('My_std', 0.012312462657174651)
# ('My_max', 0.012015663375963014)
# ('AX_entropy', 0.011579214395031383)
# ('A_mag_max', 0.01150821393550415)
# ('Fz_min', 0.011494636848908866)
# ('Fy_mean', 0.011436822811892056)
# ('AZ_min', 0.011378097328577204)
# ('Fx_skew', 0.011144452344271394)
# ('Fy_max', 0.010962858322338863)
# ('Fx_std', 0.010082326037956182)
# ('My_energy', 0.0099642517538970875)
# ('AZ_entropy', 0.0097310473771317803)
# ('F_mag_kurtosis', 0.0092792746949120417)
# ('Fz_energy', 0.0091311963416951334)
# ('Fz_mean', 0.0089843721781665015)
# ('Mx_entropy', 0.008857282557963116)
# ('AX_skew', 0.0084629051916477668)
# ('AY_min', 0.0083978590878462413)
# ('Mx_max', 0.0083330316187939357)
# ("('Fy', 'Fz')_corre", 0.008202317822511563)
# ('My_mean', 0.0081875292609773064)
# ('Mz_min', 0.0080874917461174305)
# ('A_mag_std', 0.0079604109967805151)
# ('My_entropy', 0.0077759022853849365)
# ('Mz_kurtosis', 0.0076784804223032112)
# ('Mz_skew', 0.0076721093302571063)
# ('M_mag_skew', 0.0074604538160775924)
# ('AX_max', 0.0074059944374082797)
# ("('Mx', 'My')_corre", 0.0073337906280820861)
# ('AZ_max', 0.0069863883687151952)
# ('Mz_max', 0.0068949196489636625)
# ('Fy_entropy', 0.0066267645750882507)
# ('A_mag_min', 0.0063524984636063719)
# ('AY_max', 0.0062893732636643985)
# ('M_mag_energy', 0.0056504658078300784)
# ('AZ_skew', 0.0054859558099456572)
# ('M_mag_max', 0.0053215418669267135)
# ('AX_std', 0.0052764810756528524)
# ('F_mag_min', 0.0052546913241913826)
# ('F_mag_std', 0.0051647498553099623)
# ('AZ_mean', 0.0050977955143112642)
# ('Mx_std', 0.004919553961969636)
# ('Mz_entropy', 0.004911658013934346)
# ('Fz_std', 0.0047130223535460404)
# ('My_kurtosis', 0.0046331310503993474)
# ("('Mx', 'Mz')_corre", 0.0046209810957953124)
# ('AX_mean', 0.0045496724800533316)
# ('F_mag_skew', 0.0044360016394213919)
# ('My_min', 0.0044016095365035134)
# ('Fz_max', 0.00426792946732553)
# ('AY_mean', 0.0040938714014403547)
# ('Fx_mean', 0.0040229443369344826)
# ('F_mag_energy', 0.0038800949262833926)
# ('Mz_std', 0.00370546577437266)
# ('Fy_min', 0.0036843394370602899)
# ('Fx_kurtosis', 0.0032998113588830562)
# ('AY_skew', 0.0031650543054357063)
# ('M_mag_mean', 0.0028555051507364784)
# ('Fz_entropy', 0.0028226074496066024)
# ('A_mag_energy', 0.0027326688674573973)
# ('F_mag_mean', 0.0025888439474678324)
# ('Mx_energy', 0.0025693656509201855)
# ('AZ_kurtosis', 0.0025349552181171495)
# ('Fy_kurtosis', 0.0024851808482717415)
# ('Fx_min', 0.0024324280370537996)
# ('Mz_mean', 0.0023433667445437361)
# ('AZ_energy', 0.00231421967341576)
# ('Mz_energy', 0.0022654595126039433)
# ('Fz_skew', 0.0022069453900680643)
# ('Fy_skew', 0.0021148873594183585)
# ('A_mag_kurtosis', 0.0020718703395135696)
# ('A_mag_entropy', 0.0019998516384309791)
# ('AX_kurtosis', 0.0019608820236491627)
# ("('My', 'Mz')_corre", 0.0018095297998268144)
# ('AY_energy', 0.0015797226389343)
# ('A_mag_skew', 0.0011948302423531773)
# ('AX_energy', 0.0011746795909671733)
# ('Mx_kurtosis', 0.001012515437878407)
# ('AY_kurtosis', 0.00086230415319621943)
# ('AY_std', 0.00078042004425386033)
# ('AZ_std', 0.00074878758547536036)
# ("('Fx', 'Fz')_corre", 0.00064892530391483173)
# ('M_mag_entropy', 0.00050588860416066151)
# ('A_mag_mean', 0.00040434738661543693)
# ('F_mag_max', 0.00039865793798561189)
# ('Mx_skew', 0.00015925504767391651)
# ('M_mag_std', 0.0)
# (GradientBoostingClassifier(init=None, learning_rate=0.1, loss='deviance',
#                max_depth=3, max_features='sqrt', max_leaf_nodes=None,
#                min_samples_leaf=1, min_samples_split=2,
#                min_weight_fraction_leaf=0.0, n_estimators=200,
#                presort='auto', random_state=None, subsample=1.0, verbose=0,
#                warm_start=False),
#  StandardScaler(copy=True, with_mean=True, with_std=True))

# %%
classify.do_svc_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running SVC...
# CTL size: 70 ACT size: 40
# 10-fold CV Acc Mean:  0.927272727273
# CV Scores:  0.818181818182, 0.909090909091, 1.0, 0.818181818182, 1.0, 0.909090909091, 0.909090909091, 1.0, 0.909090909091, 1.0
# (SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False),
#  StandardScaler(copy=True, with_mean=True, with_std=True))

# %%
classify.do_dnn_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running Neural Network...
# CTL size: 70 ACT size: 40
# Step #1, epoch #1, avg. loss: 1.14650
# Step #201, epoch #201, avg. loss: 0.05726
# Step #401, epoch #401, avg. loss: 0.00327
# Step #601, epoch #601, avg. loss: 0.00144
# Step #801, epoch #801, avg. loss: 0.00088
# Step #1001, epoch #1001, avg. loss: 0.00062
# Step #1201, epoch #1201, avg. loss: 0.00047
# Step #1401, epoch #1401, avg. loss: 0.00037
# Step #1601, epoch #1601, avg. loss: 0.00031
# Step #1801, epoch #1801, avg. loss: 0.00026
# Step #1, epoch #1, avg. loss: 1.15209
# Step #201, epoch #201, avg. loss: 0.04660
# Step #401, epoch #401, avg. loss: 0.00244
# Step #601, epoch #601, avg. loss: 0.00109
# Step #801, epoch #801, avg. loss: 0.00067
# Step #1001, epoch #1001, avg. loss: 0.00047
# Step #1201, epoch #1201, avg. loss: 0.00036
# Step #1401, epoch #1401, avg. loss: 0.00029
# Step #1601, epoch #1601, avg. loss: 0.00024
# Step #1801, epoch #1801, avg. loss: 0.00020
# Step #1, epoch #1, avg. loss: 1.13724
# Step #201, epoch #201, avg. loss: 0.05583
# Step #401, epoch #401, avg. loss: 0.00316
# Step #601, epoch #601, avg. loss: 0.00137
# Step #801, epoch #801, avg. loss: 0.00084
# Step #1001, epoch #1001, avg. loss: 0.00059
# Step #1201, epoch #1201, avg. loss: 0.00044
# Step #1401, epoch #1401, avg. loss: 0.00035
# Step #1601, epoch #1601, avg. loss: 0.00029
# Step #1801, epoch #1801, avg. loss: 0.00025
# Step #1, epoch #1, avg. loss: 1.15420
# Step #201, epoch #201, avg. loss: 0.05450
# Step #401, epoch #401, avg. loss: 0.00285
# Step #601, epoch #601, avg. loss: 0.00126
# Step #801, epoch #801, avg. loss: 0.00077
# Step #1001, epoch #1001, avg. loss: 0.00054
# Step #1201, epoch #1201, avg. loss: 0.00041
# Step #1401, epoch #1401, avg. loss: 0.00032
# Step #1601, epoch #1601, avg. loss: 0.00027
# Step #1801, epoch #1801, avg. loss: 0.00023
# Step #1, epoch #1, avg. loss: 1.14926
# Step #201, epoch #201, avg. loss: 0.05179
# Step #401, epoch #401, avg. loss: 0.00304
# Step #601, epoch #601, avg. loss: 0.00135
# Step #801, epoch #801, avg. loss: 0.00083
# Step #1001, epoch #1001, avg. loss: 0.00058
# Step #1201, epoch #1201, avg. loss: 0.00044
# Step #1401, epoch #1401, avg. loss: 0.00036
# Step #1601, epoch #1601, avg. loss: 0.00029
# Step #1801, epoch #1801, avg. loss: 0.00025
# Step #1, epoch #1, avg. loss: 1.19541
# Step #201, epoch #201, avg. loss: 0.05557
# Step #401, epoch #401, avg. loss: 0.00336
# Step #601, epoch #601, avg. loss: 0.00148
# Step #801, epoch #801, avg. loss: 0.00090
# Step #1001, epoch #1001, avg. loss: 0.00064
# Step #1201, epoch #1201, avg. loss: 0.00048
# Step #1401, epoch #1401, avg. loss: 0.00038
# Step #1601, epoch #1601, avg. loss: 0.00032
# Step #1801, epoch #1801, avg. loss: 0.00027
# Step #1, epoch #1, avg. loss: 1.16110
# Step #201, epoch #201, avg. loss: 0.05477
# Step #401, epoch #401, avg. loss: 0.00298
# Step #601, epoch #601, avg. loss: 0.00133
# Step #801, epoch #801, avg. loss: 0.00082
# Step #1001, epoch #1001, avg. loss: 0.00058
# Step #1201, epoch #1201, avg. loss: 0.00044
# Step #1401, epoch #1401, avg. loss: 0.00035
# Step #1601, epoch #1601, avg. loss: 0.00029
# Step #1801, epoch #1801, avg. loss: 0.00025
# Step #1, epoch #1, avg. loss: 1.18902
# Step #201, epoch #201, avg. loss: 0.05478
# Step #401, epoch #401, avg. loss: 0.00311
# Step #601, epoch #601, avg. loss: 0.00138
# Step #801, epoch #801, avg. loss: 0.00084
# Step #1001, epoch #1001, avg. loss: 0.00059
# Step #1201, epoch #1201, avg. loss: 0.00045
# Step #1401, epoch #1401, avg. loss: 0.00036
# Step #1601, epoch #1601, avg. loss: 0.00030
# Step #1801, epoch #1801, avg. loss: 0.00025
# Step #1, epoch #1, avg. loss: 1.19235
# Step #201, epoch #201, avg. loss: 0.05586
# Step #401, epoch #401, avg. loss: 0.00313
# Step #601, epoch #601, avg. loss: 0.00137
# Step #801, epoch #801, avg. loss: 0.00084
# Step #1001, epoch #1001, avg. loss: 0.00059
# Step #1201, epoch #1201, avg. loss: 0.00045
# Step #1401, epoch #1401, avg. loss: 0.00036
# Step #1601, epoch #1601, avg. loss: 0.00030
# Step #1801, epoch #1801, avg. loss: 0.00025
# Step #1, epoch #1, avg. loss: 1.20506
# Step #201, epoch #201, avg. loss: 0.04577
# Step #401, epoch #401, avg. loss: 0.00295
# Step #601, epoch #601, avg. loss: 0.00132
# Step #801, epoch #801, avg. loss: 0.00081
# Step #1001, epoch #1001, avg. loss: 0.00057
# Step #1201, epoch #1201, avg. loss: 0.00043
# Step #1401, epoch #1401, avg. loss: 0.00035
# Step #1601, epoch #1601, avg. loss: 0.00029
# Step #1801, epoch #1801, avg. loss: 0.00024
# 10-fold CV Acc Mean:  0.881818181818
# CV Scores:  1.0, 0.727272727273, 0.909090909091, 0.727272727273, 0.818181818182, 0.909090909091, 0.909090909091, 1.0, 0.909090909091, 0.909090909091
# /usr/local/lib/python2.7/site-packages/skflow/io/data_feeder.py:217: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   out.itemset((i, self.y[sample]), 1.0)
# (TensorFlowEstimator(batch_size=100, class_weight=None,
#            continue_training=False, early_stopping_rounds=None,
#            keep_checkpoint_every_n_hours=10000, learning_rate=0.1,
#            max_to_keep=5, model_fn=<function relu_dnn at 0x10be119b0>,
#            n_classes=2, num_cores=4, optimizer='SGD', steps=2000,
#            tf_master='', tf_random_seed=42, verbose=1),
#  StandardScaler(copy=True, with_mean=True, with_std=True))

# %%
classify.do_ensemble_cross_val(ctl_files=CTL_FILES, act_files=ACT_FILES)
# Out:
# Running Ensemble Cross Val...
# CTL size: 70 ACT size: 40
# Step #1, epoch #1, avg. loss: 1.16560
# Step #201, epoch #201, avg. loss: 0.05531
# Step #401, epoch #401, avg. loss: 0.00309
# Step #601, epoch #601, avg. loss: 0.00134
# Step #801, epoch #801, avg. loss: 0.00082
# Step #1001, epoch #1001, avg. loss: 0.00057
# Step #1201, epoch #1201, avg. loss: 0.00043
# Step #1401, epoch #1401, avg. loss: 0.00035
# Step #1601, epoch #1601, avg. loss: 0.00029
# Step #1801, epoch #1801, avg. loss: 0.00024
# Step #1, epoch #1, avg. loss: 1.20964
# Step #201, epoch #201, avg. loss: 0.04783
# Step #401, epoch #401, avg. loss: 0.00287
# Step #601, epoch #601, avg. loss: 0.00127
# Step #801, epoch #801, avg. loss: 0.00078
# Step #1001, epoch #1001, avg. loss: 0.00054
# Step #1201, epoch #1201, avg. loss: 0.00041
# Step #1401, epoch #1401, avg. loss: 0.00033
# Step #1601, epoch #1601, avg. loss: 0.00027
# Step #1801, epoch #1801, avg. loss: 0.00023
# Step #1, epoch #1, avg. loss: 1.19615
# Step #201, epoch #201, avg. loss: 0.04399
# Step #401, epoch #401, avg. loss: 0.00282
# Step #601, epoch #601, avg. loss: 0.00129
# Step #801, epoch #801, avg. loss: 0.00080
# Step #1001, epoch #1001, avg. loss: 0.00056
# Step #1201, epoch #1201, avg. loss: 0.00043
# Step #1401, epoch #1401, avg. loss: 0.00034
# Step #1601, epoch #1601, avg. loss: 0.00028
# Step #1801, epoch #1801, avg. loss: 0.00024
# Step #1, epoch #1, avg. loss: 1.18059
# Step #201, epoch #201, avg. loss: 0.05664
# Step #401, epoch #401, avg. loss: 0.00319
# Step #601, epoch #601, avg. loss: 0.00140
# Step #801, epoch #801, avg. loss: 0.00086
# Step #1001, epoch #1001, avg. loss: 0.00060
# Step #1201, epoch #1201, avg. loss: 0.00046
# Step #1401, epoch #1401, avg. loss: 0.00037
# Step #1601, epoch #1601, avg. loss: 0.00030
# Step #1801, epoch #1801, avg. loss: 0.00026
# Step #1, epoch #1, avg. loss: 1.17043
# Step #201, epoch #201, avg. loss: 0.05286
# Step #401, epoch #401, avg. loss: 0.00306
# Step #601, epoch #601, avg. loss: 0.00136
# Step #801, epoch #801, avg. loss: 0.00084
# Step #1001, epoch #1001, avg. loss: 0.00059
# Step #1201, epoch #1201, avg. loss: 0.00045
# Step #1401, epoch #1401, avg. loss: 0.00036
# Step #1601, epoch #1601, avg. loss: 0.00030
# Step #1801, epoch #1801, avg. loss: 0.00025
# Step #1, epoch #1, avg. loss: 1.12298
# Step #201, epoch #201, avg. loss: 0.05125
# Step #401, epoch #401, avg. loss: 0.00270
# Step #601, epoch #601, avg. loss: 0.00121
# Step #801, epoch #801, avg. loss: 0.00074
# Step #1001, epoch #1001, avg. loss: 0.00052
# Step #1201, epoch #1201, avg. loss: 0.00040
# Step #1401, epoch #1401, avg. loss: 0.00032
# Step #1601, epoch #1601, avg. loss: 0.00027
# Step #1801, epoch #1801, avg. loss: 0.00023
# Step #1, epoch #1, avg. loss: 1.15806
# Step #201, epoch #201, avg. loss: 0.05598
# Step #401, epoch #401, avg. loss: 0.00319
# Step #601, epoch #601, avg. loss: 0.00139
# Step #801, epoch #801, avg. loss: 0.00085
# Step #1001, epoch #1001, avg. loss: 0.00060
# Step #1201, epoch #1201, avg. loss: 0.00045
# Step #1401, epoch #1401, avg. loss: 0.00036
# Step #1601, epoch #1601, avg. loss: 0.00030
# Step #1801, epoch #1801, avg. loss: 0.00025
# Step #1, epoch #1, avg. loss: 1.11239
# Step #201, epoch #201, avg. loss: 0.05636
# Step #401, epoch #401, avg. loss: 0.00315
# Step #601, epoch #601, avg. loss: 0.00138
# Step #801, epoch #801, avg. loss: 0.00084
# Step #1001, epoch #1001, avg. loss: 0.00059
# Step #1201, epoch #1201, avg. loss: 0.00045
# Step #1401, epoch #1401, avg. loss: 0.00036
# Step #1601, epoch #1601, avg. loss: 0.00030
# Step #1801, epoch #1801, avg. loss: 0.00025
# Step #1, epoch #1, avg. loss: 1.20106
# Step #201, epoch #201, avg. loss: 0.05592
# Step #401, epoch #401, avg. loss: 0.00313
# Step #601, epoch #601, avg. loss: 0.00139
# Step #801, epoch #801, avg. loss: 0.00085
# Step #1001, epoch #1001, avg. loss: 0.00060
# Step #1201, epoch #1201, avg. loss: 0.00045
# Step #1401, epoch #1401, avg. loss: 0.00036
# Step #1601, epoch #1601, avg. loss: 0.00030
# Step #1801, epoch #1801, avg. loss: 0.00025
# Step #1, epoch #1, avg. loss: 1.16531
# Step #201, epoch #201, avg. loss: 0.05592
# Step #401, epoch #401, avg. loss: 0.00320
# Step #601, epoch #601, avg. loss: 0.00141
# Step #801, epoch #801, avg. loss: 0.00087
# Step #1001, epoch #1001, avg. loss: 0.00061
# Step #1201, epoch #1201, avg. loss: 0.00046
# Step #1401, epoch #1401, avg. loss: 0.00037
# Step #1601, epoch #1601, avg. loss: 0.00031
# Step #1801, epoch #1801, avg. loss: 0.00026
# 10-fold CV Acc Mean:  0.909090909091
# CV Scores:  0.818181818182, 0.727272727273, 0.818181818182, 1.0, 0.909090909091, 0.818181818182, 1.0, 1.0, 1.0, 1.0
# (VotingClassifier(estimators=[('dnn', TensorFlowEstimator(batch_size=100, class_weight=None,
#            continue_training=False, early_stopping_rounds=None,
#            keep_checkpoint_every_n_hours=10000, learning_rate=0.1,
#            max_to_keep=5, model_fn=<function relu_dnn at 0x1131791b8>,
#            n_classes=2, num...',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False))],
#           voting='soft', weights=[1, 1, 1, 1]),
#  StandardScaler(copy=True, with_mean=True, with_std=True))
