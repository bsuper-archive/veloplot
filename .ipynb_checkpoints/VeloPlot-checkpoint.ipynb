# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import utils

# %%
CALIBRATION_FILE = "N_matrix_trial9.mat"
DATA_FILE = "20_gram_lift_2016.03.16_19.54.06_trial3_imudata.txt"

utils.print_header(DATA_FILE)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-11-13e034529320> in <module>()
#       2 DATA_FILE = "20_gram_lift_2016.03.16_19.54.06_trial3_imudata.txt "
#       3
# ----> 4 utils.print_header(DATA_FILE)
#
# /Users/Can/research/veloplot/utils.pyc in print_header(data_file)
#      15     Print the experiment information
#      16     """
# ---> 17     with open(data_file, "r") as f:
#      18         print "".join([line for line in f][:7])
#      19
#
# IOError: [Errno 2] No such file or directory: '20_gram_lift_2016.03.16_19.54.06_trial3_imudata.txt '

# %%
df = utils.process_data_files(DATA_FILE, CALIBRATION_FILE)
plot_name = str(DATA_FILE.split(".txt")[0])
utils.plot_columns(df, [["TorqueL", "TorqueR"], ["Left Leg Pos", "Right Leg Pos"], ["Fx", "Fy", "Fz"], ["Mx", "My", "Mz"]], 
                   output_filename=plot_name)
# Out:
# Saving image as out/20gr_liftoff_2016.03.16_19.47.14_trial_imudata.png
# Image saved.

# %%
df.head()
# Out:
#        time  Right Leg Pos  Left Leg Pos  Commanded Right Leg Pos  \
# 0  0.000435       2.674879      4.081539                      0.0
# 1  0.001436       2.673729      4.081539                      0.0
# 2  0.002437       2.673729      4.082690                      0.0
# 3  0.003438       2.675263      4.081923                      0.0
# 4  0.004439       2.674496      4.081923                      0.0
#
#    Commanded Left Leg Pos  DCR  DCL     GyroX     GyroY     GyroZ  \
# 0                     0.0 -732  585  0.019175 -0.034088 -0.018109
# 1                     0.0 -606  560  0.021305 -0.036219 -0.018109
# 2                     0.0 -681  485  0.022371 -0.036219 -0.019175
# 3                     0.0 -782  610  0.019175 -0.035154 -0.017044
# 4                     0.0 -632  560  0.017044 -0.036219 -0.019175
#
#        ...        TorqueL      VMotorR      VMotorL    AngleZ            Fx  \
# 0      ...      -0.289902 -2756.937634  2203.290323  0.000000 -4.024325e-10
# 1      ...      -0.242554 -2282.382796  2109.132616 -0.000018 -3.555823e-09
# 2      ...      -0.264369 -2561.845520  1824.515532 -0.000037 -1.584452e-08
# 3      ...      -0.309344 -2941.796177  2294.751493 -0.000054 -4.860425e-08
# 4      ...      -0.245638 -2380.306810  2109.132616 -0.000074 -1.181530e-07
#
#              Fy            Fz            Mx            My            Mz
# 0  3.991884e-09  2.900422e-09 -1.298893e-07  2.873414e-08  2.226431e-07
# 1  3.527159e-08  2.562763e-08 -1.147679e-06  2.538898e-07  1.967235e-06
# 2  1.571679e-07  1.141950e-07 -5.113984e-06  1.131317e-06  8.765873e-06
# 3  4.821244e-07  3.503018e-07 -1.568753e-05  3.470398e-06  2.688997e-05
# 4  1.162996e-06  8.475890e-07 -3.786260e-05  8.300561e-06  6.483401e-05
#
# [5 rows x 38 columns]
