# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import utils
import featurizer
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

CALIBRATION_FILE = "N_matrix_trial9.mat"
DATA_FILE = "crashing_into_wall/5/2016.03.06_19.18.30_trial_5_imudata.txt"
df = utils.process_data_files(DATA_FILE, CALIBRATION_FILE)

# %%
df_seg = featurizer.segment(df)

for df in df_seg:
    plt.plot(df["time"], df["F_mag"])
    plt.xlabel("Time (s)")
    plt.ylabel("Force (N)")
    plt.show()

# %%
w = signal.hanning(256)

for df in df_seg:
    fft, freq = featurizer.fft_freq(df["F_mag"])
    rfft, rfreq = featurizer.rfft_freq(df["F_mag"])
    print "FFT Frequency domain entropy:", featurizer.freq_domain_entropy(fft), "Energy:", featurizer.energy(fft)
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 3, 1)
    plt.plot(df["time"], df["F_mag"])
    plt.xlabel("Time (s)")
    plt.ylabel("Force (N)")
    plt.title("Before Hanning")
    plt.subplot(1, 3, 2)
    plt.plot(df["time"], df["F_mag"] * w)
    plt.xlabel("Time (s)")
    plt.ylabel("Force (N)")
    plt.title("After Hanning")
    plt.subplot(1, 3, 3)
    plt.bar(freq, np.abs(fft))
    plt.xlim([0, 50])
    plt.xlabel("Frequency")
    plt.ylabel("|Amplitude|")
    plt.tight_layout()
    plt.show()
# Out:
# Frequency domain entropy: 1.1840177922 Energy: 1.54673232763
# Frequency domain entropy: 0.98223801802 Energy: 215.455703963
# Frequency domain entropy: 1.19514133747 Energy: 320.387717095
# Frequency domain entropy: 1.05211940432 Energy: 704.276761017
# Frequency domain entropy: 0.994616062885 Energy: 270.857486117
# Frequency domain entropy: 0.693536767685 Energy: 703.516118498
# Frequency domain entropy: 1.17991369621 Energy: 2716.66888371
# Frequency domain entropy: 0.82926277707 Energy: 1728.47881469
